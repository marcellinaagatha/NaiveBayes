# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/Naive Bayes.xlsx')

# %%
data.head()
# Out:
#        Day Discount Free delivery Purchase
# 0  Holiday      Yes            No      Yes
# 1  Weekday      Yes           Yes       No
# 2  Weekend       No           Yes      Yes
# 3  Weekday       No            No       No
# 4  Holiday      Yes           Yes      Yes

# %%
data.shape
# Out:
# (20, 4)

# %%
data['Purchase'].value_counts()
# Out:
# Purchase
# Yes    13
# No      7
# Name: count, dtype: int64

# %%
pYes = 13/20
pNo = 7/20

# %%
print(pYes)
# Out:
# 0.65

# %%
print(pNo)
# Out:
# 0.35

# %%
pd.crosstab(data['Day'], data['Purchase'])
# Out:
# Purchase  No  Yes
# Day
# Holiday    1    5
# Weekday    3    3
# Weekend    3    5

# %%
pHolidayNo = 1/7
pWeekdayNo = 3/7
pWeekendNo = 3/7

pHolidayYes = 5/13
pWeekdayYes = 3/13
pWeekendYes = 5/13

pHoliday = 6/20
pWeekday = 6/20
pWeekend = 8/20

print(pWeekdayYes)
# Out:
# 0.23076923076923078

# %%
pNoWeekday = (pWeekdayNo * pNo) / pWeekday
pNoWeekday
# Out:
# 0.5

# %%
pYesWeekday = (pWeekdayYes * pYes) / pWeekday
pYesWeekday
# Out:
# 0.5000000000000001

# %%
pd.crosstab(data['Discount'],data['Purchase'])
# Out:
# Purchase  No  Yes
# Discount
# No         3    5
# Yes        4    8

# %%
pNoDiscountNo = 3/7
pYesDiscountNo = 5/7

pNoDiscountYes = 4/13
pYesDiscountYes = 8/13

pDiscountNo = 8/20
pDiscountYes = 12/20

# %%
pd.crosstab(data['Free delivery'],data['Purchase'])
# Out:
# Purchase       No  Yes
# Free delivery
# No              6    5
# Yes             1    8

# %%
pNoFDNo = 6/7
pYesFDNo = 5/7

pNoFDYes = 1/13
pYesFDYes = 8/13

pFDNo = 7/20
pFDYes = 13/20

# %%
PNoBuy1 = ((pWeekdayNo*pNoDiscountYes*pNoFDYes)*pNo) / (pWeekday*pDiscountYes*pFDYes)

PNoBuy1
# Out:
# 0.030344409042633896

# %%
PNoBuy2 = ((pHolidayNo*pNoDiscountYes*pNoFDYes)*pNo) / (pHoliday*pDiscountYes*pFDYes)

PNoBuy2
# Out:
# 0.010114803014211301

# %%
pSum = PNoBuy1 + PNoBuy2

pSum
# Out:
# 0.0404592120568452

# %%
pBuy = (PNoBuy2/pSum) * 100
pBuy
# Out:
# 25.000000000000007

# %%
pNoBuy = (PNoBuy1*pSum) * 100

pNoBuy
# Out:
# 0.12277108801955756
